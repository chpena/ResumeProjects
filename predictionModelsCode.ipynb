# %%
import numpy as np
import pandas as pd
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn.metrics import mean_absolute_error
from sklearn.externals import joblib
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
# Use to remove special characters and remove whitespace from player names

# wrs20clean1['Player'] = wrs20clean1['Player'].str.replace('[*,+]','')
# wrs20clean1.Player = wrs20clean1.Player.str.strip()
# wrs19clean1.Player = wrs19clean1.Player.str.replace('[*,+]','')
# wrs19clean1.Player = wrs19clean1.Player.str.strip()
# wrs18clean1.Player = wrs18clean1.Player.str.replace('[*,+]','')
# wrs18clean1.Player = wrs18clean1.Player.str.strip()

# Use to export as Excel workbook for Power BI import

# wrs20clean1.to_excel(r'‪2020clean1.xlsx', index = False)
# wrs19clean1.to_excel(r'2019clean1.xlsx', index = False)
# wrs18clean1.to_excel(r'‪2018clean1.xlsx', index = False)

# %%
dataset = pd.read_excel("2020predictions.xlsx")

# Make a copy to add predictions back to dataset - Issues with le.transform_inverse()
datafinal = dataset.copy()

# Can be used to remove other unnecessary columns
datasetclean = dataset.drop(columns=['Rk','Pos','Rec','R/G'])
#datasetclean = dataset.drop(columns=['Rk','Pos','Rec','R/G','Rk_20',
#                                      'Pos_20','Rec_20','R/G_20','Rk_19',
#                                      'Pos_19','Rec_19','R/G_19','Tm',
#                                      'Tm_19','Tm_20'])

# Convert Player and team names to numeric values for model
le = LabelEncoder()
datasetclean['Player'] = le.fit_transform(datasetclean['Player'])
datasetclean['Tm'] = le.fit_transform(datasetclean['Tm'])
### Issues with running le.fit_transform on 'Tm'. Error stating arg needs to be str or number - names are strings, NaNs filled with 0. 
### Decided to simply drop Team from dataset.

# Continue pre-processing data
y = datasetclean['Tgt']
X = datasetclean.copy().drop(columns=['Tgt'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
### We can verify all categorical values have been converted to numeric. 

#X_train
#y_train
#X

# %%
### With certain datasets, converting y_train to int type is required.
### This is as a result of the Label Encoder multiclass type as 'continous'
### https://stackoverflow.com/questions/41925157/logisticregression-unknown-label-type-continuous-using-sklearn-in-python

# int_y = y_train.astype('int64')
# int_y

# %%
# Gradient Boosting prediction model

gradRegressor = ensemble.GradientBoostingRegressor(
    n_estimators=1000,
    learning_rate=0.1,
    max_depth=6,
    min_samples_leaf=9,
    max_features=0.1,
    loss='huber',
    random_state=0)

# import warnings
# warnings.filterwarnings("ignore")

gradRegressor.fit(X_train, y_train)

grPredict = gradRegressor.predict(X)

datafinal['gbr_prediction'] = grPredict

# %%
mse = mean_absolute_error(y_train, gradRegressor.predict(X_train))
print("Training Set Mean Absolute Error: %.4f" % mse)

### Find the error rate on the test set
mse = mean_absolute_error(y_test, gradRegressor.predict(X_test))
print("Test Set Mean Absolute Error: %.4f" % mse)
# Out:
# Training Set Mean Absolute Error: 0.2135
# Test Set Mean Absolute Error: 7.2147

# %%
# Logistic Regression prediction model

log = LogisticRegression()
log.fit(X_train, y_train)
lrPredict = log.predict(X)
lrProba = log.predict_proba(X)[:,1]

datafinal['lr_prediction'] = lrPredict
datafinal['lr_probability'] = lrProba

# %%
lr_mse = mean_absolute_error(y_train, log.predict(X_train))
print("Training mse: %.4f" % lr_mse)

lr_mse = mean_absolute_error(y_test, log.predict(X_test))
print("Training mse: %.4f" % lr_mse)
# Out:
# Training mse: 0.3622
# Training mse: 18.9455

# %%
datafinal.head(20)
# Out:
#     Unnamed: 0  Rk               Player   Tm  Age Pos   G  GS  Tgt  Rec  ...  \
# 0            0   1         Stefon Diggs  BUF   27  WR  16  15  166  127  ...
# 1            1   3      DeAndre Hopkins  ARI   28  WR  16  16  160  115  ...
# 2            2   6       Allen Robinson  CHI   27  WR  16  16  151  102  ...
# 3            3   2        Davante Adams  GNB   28  WR  14  14  149  115  ...
# 4            4   7         Keenan Allen  LAC   28  WR  14  13  147  100  ...
# 5            5  16      Diontae Johnson  PIT   24  WR  15  13  144   88  ...
# 6            6  13        Calvin Ridley  ATL   26  WR  15  15  143   90  ...
# 7            7  10       Robby Anderson  CAR   27  WR  16  16  136   95  ...
# 8            8  17          Tyreek Hill  KAN   26  WR  15  15  135   87  ...
# 9            9  18       Terry McLaurin  WAS   25  WR  15  15  134   87  ...
# 10          10   8        Tyler Lockett  SEA   28  WR  16  16  132  100  ...
# 11          11  11         Amari Cooper  DAL   26  WR  16  15  130   92  ...
# 12          12  20         D.K. Metcalf  SEA   23  WR  16  16  129   83  ...
# 13          13  14         Robert Woods  LAR   28  WR  16  16  129   90  ...
# 14          14   9  JuJu Smith-Schuster  PIT   24  WR  16  14  128   97  ...
# 15          15  15     Justin Jefferson  MIN   21  WR  16  14  125   88  ...
# 16          16  12          Cooper Kupp  LAR   27  WR  15  12  124   92  ...
# 17          17  22        Brandin Cooks  HOU   27  WR  15  15  119   81  ...
# 18          18  36           D.J. Moore  CAR   23  WR  15  14  118   66  ...
# 19          19  26         Marvin Jones  DET   30  WR  16  16  115   76  ...
#
#     TD  1D  Lng  Y/Tgt  R/G   Y/G  Fmb  gbr_prediction  lr_prediction  \
# 0    8  73   55    9.2  7.9  95.9    0      155.938817            166
# 1    6  75   60    8.8  7.2  87.9    3      157.174171            160
# 2    6  68   42    8.3  6.4  78.1    0      150.997454            151
# 3   18  73   56    9.2  8.2  98.1    1      149.003512            149
# 4    8  61   28    6.7  7.1  70.9    3      114.446270            103
# 5    7  45   47    6.4  5.9  61.5    2      123.043581            128
# 6    9  65   63    9.6  6.0  91.6    1      142.998443            143
# 7    3  49   75    8.1  5.9  68.5    1      124.681308            129
# 8   15  57   75    9.5  5.8  85.1    1      130.724830             50
# 9    4  51   68    8.3  5.8  74.5    1      133.990651            134
# 10  10  57   47    8.0  6.3  65.9    1      132.007239            132
# 11   5  54   69    8.6  5.8  69.6    0      131.351688            130
# 12  10  63   62   10.1  5.2  81.4    1      135.643468            129
# 13   6  44   56    7.3  5.6  58.5    2      129.004878            129
# 14   9  48   31    6.5  6.1  51.9    3      127.994421            128
# 15   7  58   71   11.2  5.5  87.5    1      124.996691            125
# 16   3  44   55    7.9  6.1  64.9    1      102.660116             22
# 17   6  51   57    9.7  5.4  76.7    0      119.860272            119
# 18   4  53   74   10.1  4.4  79.5    0      110.560812             48
# 19   9  52   43    8.5  4.8  61.1    0      110.579462             59
#
#     lr_probability
# 0    1.655139e-143
# 1    1.220477e-134
# 2    8.864413e-125
# 3    5.377478e-131
# 4     6.631452e-95
# 5     1.110157e-89
# 6    8.355086e-129
# 7     2.032166e-90
# 8    1.897804e-106
# 9    4.521086e-104
# 10   3.054518e-101
# 11   5.369237e-104
# 12   7.206042e-119
# 13    3.328988e-90
# 14    5.732250e-87
# 15   1.011234e-122
# 16    2.342494e-82
# 17   3.920893e-106
# 18   1.906022e-110
# 19    1.317165e-88
#
# [20 rows x 23 columns]

# %%
### Export file to Excel

datafinal.to_excel(r'avgFilled2021predictions.xlsx')

# %%
### For plotting purposes, we can remove predicted target values of less than 100.

gt100 = datafinal[datafinal.gbr_prediction > 100]
gt100
# Out:
#     Unnamed: 0  Rk               Player   Tm  Age Pos   G  GS  Tgt  Rec  ...  \
# 0            0   1         Stefon Diggs  BUF   27  WR  16  15  166  127  ...
# 1            1   3      DeAndre Hopkins  ARI   28  WR  16  16  160  115  ...
# 2            2   6       Allen Robinson  CHI   27  WR  16  16  151  102  ...
# 3            3   2        Davante Adams  GNB   28  WR  14  14  149  115  ...
# 4            4   7         Keenan Allen  LAC   28  WR  14  13  147  100  ...
# 5            5  16      Diontae Johnson  PIT   24  WR  15  13  144   88  ...
# 6            6  13        Calvin Ridley  ATL   26  WR  15  15  143   90  ...
# 7            7  10       Robby Anderson  CAR   27  WR  16  16  136   95  ...
# 8            8  17          Tyreek Hill  KAN   26  WR  15  15  135   87  ...
# 9            9  18       Terry McLaurin  WAS   25  WR  15  15  134   87  ...
# 10          10   8        Tyler Lockett  SEA   28  WR  16  16  132  100  ...
# 11          11  11         Amari Cooper  DAL   26  WR  16  15  130   92  ...
# 12          12  20         D.K. Metcalf  SEA   23  WR  16  16  129   83  ...
# 13          13  14         Robert Woods  LAR   28  WR  16  16  129   90  ...
# 14          14   9  JuJu Smith-Schuster  PIT   24  WR  16  14  128   97  ...
# 15          15  15     Justin Jefferson  MIN   21  WR  16  14  125   88  ...
# 16          16  12          Cooper Kupp  LAR   27  WR  15  12  124   92  ...
# 17          17  22        Brandin Cooks  HOU   27  WR  15  15  119   81  ...
# 18          18  36           D.J. Moore  CAR   23  WR  15  14  118   66  ...
# 19          19  26         Marvin Jones  DET   30  WR  16  16  115   76  ...
# 20          20  71          Jerry Jeudy  DEN   21  WR  16  14  113   52  ...
# 21          21  27          CeeDee Lamb  DAL   21  WR  16  14  111   74  ...
# 22          22  24           Tyler Boyd  CIN   26  WR  15   8  110   79  ...
# 23          23  44       Chase Claypool  PIT   22  WR  16   6  109   62  ...
# 24          24  33           Mike Evans  TAM   27  WR  16  16  109   70  ...
# 25          25  29         Russell Gage  ATL   24  WR  16   8  109   72  ...
# 26          26  34          Tee Higgins  CIN   21  WR  16  14  108   67  ...
# 27          27  28         Adam Thielen  MIN   30  WR  15  15  108   74  ...
# 28          28  21         Cole Beasley  BUF   31  WR  15  10  107   82  ...
# 29          29  32           A.J. Brown  TEN   23  WR  14  12  106   70  ...
# 30          30  52       Michael Gallup  DAL   24  WR  16  15  105   59  ...
# 21    3.023708e-89
# 22    3.741691e-76
# 23    6.503509e-78
# 24    2.444769e-94
# 25    1.727591e-79
# 26    1.114801e-81
# 27    2.228168e-87
# 28    1.401109e-92
# 29    6.801585e-96
# 30    3.113957e-78
# 31    3.363421e-60
# 32    1.501350e-80
# 33    6.953936e-82
# 34    5.480456e-70
#
# [35 rows x 23 columns]

# %%
### Adjust figure size if desired

plt.figure(figsize=(10,10))

visual = sns.lineplot(data=gt100, x="Player", y="gbr_prediction")
visual.set_xticklabels(gt100['Player'], rotation=90, ha="center")
plt.tight_layout()
plt.show()

# %%
avgFilled = pd.read_excel(r'avgFilled2021predictions.xlsx')

# %%
avg100 = avgFilled[avgFilled.gbr_prediction > 100]
avg100
# Out:
#     Unnamed: 0  Unnamed: 0.1  Rk               Player   Tm  Age Pos   G  GS  \
# 0            0             0   1         Stefon Diggs  BUF   27  WR  16  15
# 1            1             1   3      DeAndre Hopkins  ARI   28  WR  16  16
# 2            2             2   6       Allen Robinson  CHI   27  WR  16  16
# 3            3             3   2        Davante Adams  GNB   28  WR  14  14
# 4            4             4   7         Keenan Allen  LAC   28  WR  14  13
# 5            5             5  16      Diontae Johnson  PIT   24  WR  15  13
# 6            6             6  13        Calvin Ridley  ATL   26  WR  15  15
# 7            7             7  10       Robby Anderson  CAR   27  WR  16  16
# 8            8             8  17          Tyreek Hill  KAN   26  WR  15  15
# 9            9             9  18       Terry McLaurin  WAS   25  WR  15  15
# 10          10            10   8        Tyler Lockett  SEA   28  WR  16  16
# 11          11            11  11         Amari Cooper  DAL   26  WR  16  15
# 12          12            12  20         D.K. Metcalf  SEA   23  WR  16  16
# 13          13            13  14         Robert Woods  LAR   28  WR  16  16
# 14          14            14   9  JuJu Smith-Schuster  PIT   24  WR  16  14
# 15          15            15  15     Justin Jefferson  MIN   21  WR  16  14
# 16          16            16  12          Cooper Kupp  LAR   27  WR  15  12
# 17          17            17  22        Brandin Cooks  HOU   27  WR  15  15
# 18          18            18  36           D.J. Moore  CAR   23  WR  15  14
# 19          19            19  26         Marvin Jones  DET   30  WR  16  16
# 20          20            20  71          Jerry Jeudy  DEN   21  WR  16  14
# 21          21            21  27          CeeDee Lamb  DAL   21  WR  16  14
# 22          22            22  24           Tyler Boyd  CIN   26  WR  15   8
# 23          23            23  44       Chase Claypool  PIT   22  WR  16   6
# 24          24            24  33           Mike Evans  TAM   27  WR  16  16
# 25          25            25  29         Russell Gage  ATL   24  WR  16   8
# 26          26            26  34          Tee Higgins  CIN   21  WR  16  14
# 27          27            27  28         Adam Thielen  MIN   30  WR  15  15
# 28          28            28  21         Cole Beasley  BUF   31  WR  15  10
# 29          29            29  32           A.J. Brown  TEN   23  WR  14  12
# 30          30            30  52       Michael Gallup  DAL   24  WR  16  15
# 31          31            31  88           A.J. Green  CIN   32  WR  16  14
# 32          32            32  42       DeVante Parker  MIA   27  WR  14  11
# 33          33            33  30        Jarvis Landry  CLE   28  WR  15  14
# 34          34            34  55       Marquise Brown  BAL   23  WR  16  14
#
# 22            110    3.741691e-76
# 23            109    6.503509e-78
# 24             93    2.444769e-94
# 25            109    1.727591e-79
# 26             93    1.114801e-81
# 27            108    2.228168e-87
# 28            107    1.401109e-92
# 29            106    6.801585e-96
# 30             93    3.113957e-78
# 31            104    3.363421e-60
# 32            103    1.501350e-80
# 33             22    6.953936e-82
# 34            100    5.480456e-70
#
# [35 rows x 24 columns]

# %%
plt.figure(figsize=(10,10))

visual = sns.lineplot(data=avg100, x="Player", y="gbr_prediction")
visual.set_xticklabels(avg100['Player'], rotation=90, ha="center")
plt.tight_layout()
plt.show()

# %%
addExtra = pd.read_excel('2020predictions.xlsx')
addExtra.head(15)
# Out:
#     Unnamed: 0  Rk               Player   Tm  Age Pos   G  GS  Tgt  Rec  ...  \
# 0            0   1         Stefon Diggs  BUF   27  WR  16  15  166  127  ...
# 1            1   3      DeAndre Hopkins  ARI   28  WR  16  16  160  115  ...
# 2            2   6       Allen Robinson  CHI   27  WR  16  16  151  102  ...
# 3            3   2        Davante Adams  GNB   28  WR  14  14  149  115  ...
# 4            4   7         Keenan Allen  LAC   28  WR  14  13  147  100  ...
# 5            5  16      Diontae Johnson  PIT   24  WR  15  13  144   88  ...
# 6            6  13        Calvin Ridley  ATL   26  WR  15  15  143   90  ...
# 7            7  10       Robby Anderson  CAR   27  WR  16  16  136   95  ...
# 8            8  17          Tyreek Hill  KAN   26  WR  15  15  135   87  ...
# 9            9  18       Terry McLaurin  WAS   25  WR  15  15  134   87  ...
# 10          10   8        Tyler Lockett  SEA   28  WR  16  16  132  100  ...
# 11          11  11         Amari Cooper  DAL   26  WR  16  15  130   92  ...
# 12          12  20         D.K. Metcalf  SEA   23  WR  16  16  129   83  ...
# 13          13  14         Robert Woods  LAR   28  WR  16  16  129   90  ...
# 14          14   9  JuJu Smith-Schuster  PIT   24  WR  16  14  128   97  ...
#
#     TD  1D  Lng  Y/Tgt  R/G   Y/G  Fmb  gbr_prediction  lr_prediction  \
# 0    8  73   55    9.2  7.9  95.9    0      154.664976            166
# 1    6  75   60    8.8  7.2  87.9    3      160.000590            160
# 2    6  68   42    8.3  6.4  78.1    0      148.189306            151
# 3   18  73   56    9.2  8.2  98.1    1      149.001045            149
# 4    8  61   28    6.7  7.1  70.9    3      104.996185            103
# 5    7  45   47    6.4  5.9  61.5    2      107.680483            129
# 6    9  65   63    9.6  6.0  91.6    1      143.004495            143
# 7    3  49   75    8.1  5.9  68.5    1      135.959329             61
# 8   15  57   75    9.5  5.8  85.1    1      129.330531             82
# 9    4  51   68    8.3  5.8  74.5    1      133.587909            134
# 10  10  57   47    8.0  6.3  65.9    1      132.004493            132
# 11   5  54   69    8.6  5.8  69.6    0      130.000706            130
# 12  10  63   62   10.1  5.2  81.4    1      128.996423            129
# 13   6  44   56    7.3  5.6  58.5    2      128.998974            129
# 14   9  48   31    6.5  6.1  51.9    3      119.596890            128
#
#     lr_probability
# 0    1.686517e-145
# 1    7.584306e-134
# 2    9.013635e-124
# 3    1.073146e-133
# 4    6.741650e-100
# 5     1.517997e-86
# 6    3.871340e-132
# 7     2.681078e-96
# 8    7.002097e-116
# 9    1.899441e-101
# 10    3.504956e-98
# 11   8.197211e-103
# 12   1.914365e-123
# 13    1.178898e-83
# 14    9.333824e-80
#
# [15 rows x 23 columns]

# %%
beforeAdd = addExtra.gbr_prediction
# Out:
# 0      154.664976
# 1      160.000590
# 2      148.189306
# 3      149.001045
# 4      104.996185
#           ...
# 177      4.510055
# 178      4.005463
# 179     13.218970
# 180      4.000906
# 181      4.288523
# Name: gbr_prediction, Length: 182, dtype: float64

# %%
def extraGame(x):
    game17 = np.divide(x,16)
    return  x + game17

# %%
afterAdd = extraGame(beforeAdd)

# %%
afterAdd
# Out:
# 0      164.331536
# 1      170.000627
# 2      157.451138
# 3      158.313610
# 4      111.558447
#           ...
# 177      4.791933
# 178      4.255805
# 179     14.045155
# 180      4.250963
# 181      4.556556
# Name: gbr_prediction, Length: 182, dtype: float64

# %%
addExtra.gbr_prediction = afterAdd

# %%
addExtra
# Out:
#      Unnamed: 0   Rk               Player   Tm  Age Pos   G  GS  Tgt  Rec  \
# 0             0    1         Stefon Diggs  BUF   27  WR  16  15  166  127
# 1             1    3      DeAndre Hopkins  ARI   28  WR  16  16  160  115
# 2             2    6       Allen Robinson  CHI   27  WR  16  16  151  102
# 3             3    2        Davante Adams  GNB   28  WR  14  14  149  115
# 4             4    7         Keenan Allen  LAC   28  WR  14  13  147  100
# ..          ...  ...                  ...  ...  ...  ..  ..  ..  ...  ...
# 177         177  399  Lil'Jordan Humphrey  NOR   22  WR   3   1    5    3
# 178         178  419     Antonio Callaway  MIA   23  WR   5   1    4    2
# 179         179  411      Brandon Zylstra  CAR   27  WR  16   2    4    3
# 180         180  385         Riley Ridley  CHI   24  WR   5   1    4    4
# 181         181  484         Jaleel Scott  NYJ   25  WR   1   1    1    1
#
#      ...  TD  1D  Lng  Y/Tgt  R/G   Y/G  Fmb  gbr_prediction  lr_prediction  \
# 0    ...   8  73   55    9.2  7.9  95.9    0      164.331536            166
# 1    ...   6  75   60    8.8  7.2  87.9    3      170.000627            160
# 2    ...   6  68   42    8.3  6.4  78.1    0      157.451138            151
# 3    ...  18  73   56    9.2  8.2  98.1    1      158.313610            149
# 4    ...   8  61   28    6.7  7.1  70.9    3      111.558447            103
# ..   ...  ..  ..  ...    ...  ...   ...  ...             ...            ...
# 177  ...   1   3   17    9.2  1.0  15.3    0        4.791933              8
# 178  ...   0   1   13    5.0  0.4   4.0    0        4.255805              4
# 179  ...   0   3   28    8.8  0.2   2.2    0       14.045155              6
# 180  ...   0   3   18    9.8  0.8   7.8    0        4.250963              4
# 181  ...   0   1   16   16.0  1.0  16.0    0        4.556556              4
#
#      lr_probability
# 0     1.686517e-145
# 1     7.584306e-134
# 2     9.013635e-124
# 3     1.073146e-133
# 4     6.741650e-100
# ..              ...
# 177    3.726160e-07
# 178    5.798766e-04
# 179    9.561796e-02
# 180    6.879953e-02
# 181    2.000951e-05
#
# [182 rows x 23 columns]

# %%
addExtra.to_excel(r'17gamePredictions.xlsx')
